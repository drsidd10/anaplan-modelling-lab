# %% [markdown]
# # 08 — Saved Views, Actions & ALM Simulation
# This notebook demonstrates Saved Views, Actions, and ALM simulation.

# %%
import xarray as xr
import pandas as pd
from saved_views import create_saved_view
from actions import export_to_csv, import_from_csv
from alm import create_branch, create_revision_tag

# %% [markdown]
# ## 1. Example Dataset

# %%
ds = xr.Dataset({
    'Revenue': (['time'], [100,200,300]),
    'Cost': (['time'], [50,60,70])
}, coords={'time':['2026Q1','2026Q2','2026Q3']})
ds

# %% [markdown]
# ## 2. Create Saved View

# %%
view = create_saved_view(ds, {'time':['2026Q1','2026Q3']})
view

# %% [markdown]
# ## 3. Export Saved View to CSV

# %%
file = export_to_csv(view, 'saved_view.csv')
file

# %% [markdown]
# ## 4. Import CSV Back (Action Simulation)

# %%
df = import_from_csv('saved_view.csv')
df.head()

# %% [markdown]
# ## 5. ALM Simulation (Branch + Revision Tag)

# %%
create_branch('dev_day8')
create_revision_tag('rev_day8')
