# %% [markdown]
# # 07 — Connected Planning Summary (GitHub-Safe Version)
# This notebook integrates FP&A, Workforce, and S&OP outputs using consolidated modules.

# %%
import xarray as xr
from connected_summary import consolidate
from connected_kpis import extract_kpis

# %% [markdown]
# ## Load Input Domains
# Load FP&A, Workforce, and S&OP datasets.

# %%
# Example: Replace with real loaded datasets when available
fpna = xr.Dataset({'Revenue': (['time'], [1,2,3]), 'EBITDA':(['time'],[1,2,3]), 'FCF':(['time'],[1,2,3]), 'NPV':(['scenario'],[100])})
workforce = xr.Dataset({'Cost': (['time'], [5,6,7])})
sop = xr.Dataset({'Inventory': (['time'], [10,20,30])})

# %% [markdown]
# ## Consolidate All Planning Domains

# %%
consolidated = consolidate(fpna, workforce, sop)
consolidated

# %% [markdown]
# ## Extract KPIs

# %%
kpis = extract_kpis(consolidated)
kpis
